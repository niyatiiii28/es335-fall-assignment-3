# %%
import torch
import torch.nn.functional as F
from torch import nn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from sklearn.manifold import TSNE


# Load dataset
def load_data(file_path):
    with open(file_path, 'r') as file:
        text = file.read()
    return text

# Clean text
def clean_text(text):
    text = re.sub('[^a-zA-Z0-9 \.]', '', text)  # Remove special characters
    text = text.lower()
    return text

# Prepare data
text = load_data('/content/sherlock.txt')  # Replace with your dataset path
cleaned_text = clean_text(text)
words = cleaned_text.split()

# Create vocabulary
unique_words = sorted(set(words))
stoi = {s: i + 1 for i, s in enumerate(unique_words)}  # String to index
itos = {i: s for s, i in stoi.items()}  # Index to string

print(f"Vocabulary Size: {len(stoi)}")
# Out:
# Vocabulary Size: 16821

# %%
import torch
torch.cuda.is_available()  # Returns True if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
block_size = 10  # Number of words to predict the next one
X, Y = [], []

for i in range(len(words) - block_size):
    context = words[i:i + block_size]  # Get the context of words
    next_word = words[i + block_size]  # Get the next word
    X.append([stoi[w] for w in context])  # Append the context as indices
    Y.append(stoi[next_word])  # Append the next word index

# Convert to tensors
X = torch.tensor(X)
Y = torch.tensor(Y)

# Print the input-output pairs
for i in range(len(X)):
    context_words = [itos[idx.item()] for idx in X[i]]  # Convert indices back to words
    next_word = itos[Y[i].item()]  # Convert index to word
    print(f" {' '.join(context_words)} --->  {next_word}")
# Out:
# Streaming output truncated to the last 5000 lines.
#  the arms of mr. rucastle who was waitingoutside.so said he --->  smiling
#  arms of mr. rucastle who was waitingoutside.so said he smiling --->  it
#  of mr. rucastle who was waitingoutside.so said he smiling it --->  was
#  mr. rucastle who was waitingoutside.so said he smiling it was --->  you
#  rucastle who was waitingoutside.so said he smiling it was you --->  then.
#  who was waitingoutside.so said he smiling it was you then. --->  i
#  was waitingoutside.so said he smiling it was you then. i --->  thought
#  waitingoutside.so said he smiling it was you then. i thought --->  that
#  said he smiling it was you then. i thought that --->  it
#  he smiling it was you then. i thought that it --->  must
#  smiling it was you then. i thought that it must --->  bewhen
#  it was you then. i thought that it must bewhen --->  i
#  was you then. i thought that it must bewhen i --->  saw
#  you then. i thought that it must bewhen i saw --->  the
#  then. i thought that it must bewhen i saw the --->  door
#  i thought that it must bewhen i saw the door --->  open.oh
#  thought that it must bewhen i saw the door open.oh --->  i
#  that it must bewhen i saw the door open.oh i --->  am
#  it must bewhen i saw the door open.oh i am --->  so
#  must bewhen i saw the door open.oh i am so --->  frightened
#  bewhen i saw the door open.oh i am so frightened --->  i
#  i saw the door open.oh i am so frightened i --->  panted.my
#  saw the door open.oh i am so frightened i panted.my --->  dear
#  the door open.oh i am so frightened i panted.my dear --->  young
#  door open.oh i am so frightened i panted.my dear young --->  lady
#  open.oh i am so frightened i panted.my dear young lady --->  my
#  i am so frightened i panted.my dear young lady my --->  dear
#  am so frightened i panted.my dear young lady my dear --->  young
#  so frightened i panted.my dear young lady my dear young --->  ladyyou
#  frightened i panted.my dear young lady my dear young ladyyou --->  cannot
#  i panted.my dear young lady my dear young ladyyou cannot --->  think
#  panted.my dear young lady my dear young ladyyou cannot think --->  howcaressing
#  dear young lady my dear young ladyyou cannot think howcaressing --->  and
#  young lady my dear young ladyyou cannot think howcaressing and --->  soothing
#  lady my dear young ladyyou cannot think howcaressing and soothing --->  his
#  my dear young ladyyou cannot think howcaressing and soothing his --->  manner
#  dear young ladyyou cannot think howcaressing and soothing his manner --->  wasand
#  young ladyyou cannot think howcaressing and soothing his manner wasand --->  what
#  ladyyou cannot think howcaressing and soothing his manner wasand what --->  has
#  cannot think howcaressing and soothing his manner wasand what has --->  frightened
#  think howcaressing and soothing his manner wasand what has frightened --->  you
#  howcaressing and soothing his manner wasand what has frightened you --->  mydear
#  and soothing his manner wasand what has frightened you mydear --->  young
#  soothing his manner wasand what has frightened you mydear young --->  ladybut
#  his manner wasand what has frightened you mydear young ladybut --->  his
#  manner wasand what has frightened you mydear young ladybut his --->  voice
#  wasand what has frightened you mydear young ladybut his voice --->  was
#  what has frightened you mydear young ladybut his voice was --->  just
#  has frightened you mydear young ladybut his voice was just --->  a
#  frightened you mydear young ladybut his voice was just a --->  little
#  you mydear young ladybut his voice was just a little --->  too
#  mydear young ladybut his voice was just a little too --->  coaxing.
#  young ladybut his voice was just a little too coaxing. --->  he
#  ladybut his voice was just a little too coaxing. he --->  overdid
#  his voice was just a little too coaxing. he overdid --->  it.
#  voice was just a little too coaxing. he overdid it. --->  i
#  was just a little too coaxing. he overdid it. i --->  waskeenly
#  just a little too coaxing. he overdid it. i waskeenly --->  on
#  a little too coaxing. he overdid it. i waskeenly on --->  my
#  little too coaxing. he overdid it. i waskeenly on my --->  guard
#  too coaxing. he overdid it. i waskeenly on my guard --->  against
#  coaxing. he overdid it. i waskeenly on my guard against --->  him.i
#  he overdid it. i waskeenly on my guard against him.i --->  was
#  overdid it. i waskeenly on my guard against him.i was --->  foolish
#  it. i waskeenly on my guard against him.i was foolish --->  enough
#  i waskeenly on my guard against him.i was foolish enough --->  to
#  waskeenly on my guard against him.i was foolish enough to --->  go
#  on my guard against him.i was foolish enough to go --->  into
#  my guard against him.i was foolish enough to go into --->  the
#  guard against him.i was foolish enough to go into the --->  empty
#  against him.i was foolish enough to go into the empty --->  wing
#  him.i was foolish enough to go into the empty wing --->  i
#  was foolish enough to go into the empty wing i --->  answered.
#  foolish enough to go into the empty wing i answered. --->  but
#  enough to go into the empty wing i answered. but --->  itis
#  to go into the empty wing i answered. but itis --->  so
#  go into the empty wing i answered. but itis so --->  lonely
#  into the empty wing i answered. but itis so lonely --->  and
#  the empty wing i answered. but itis so lonely and --->  eerie
#  empty wing i answered. but itis so lonely and eerie --->  in
#  wing i answered. but itis so lonely and eerie in --->  this
#  i answered. but itis so lonely and eerie in this --->  dim
#  answered. but itis so lonely and eerie in this dim --->  light
#  but itis so lonely and eerie in this dim light --->  that
#  itis so lonely and eerie in this dim light that --->  i
#  so lonely and eerie in this dim light that i --->  was
#  lonely and eerie in this dim light that i was --->  frightened
#  and eerie in this dim light that i was frightened --->  and
#  eerie in this dim light that i was frightened and --->  ranout
#  in this dim light that i was frightened and ranout --->  again.
#  this dim light that i was frightened and ranout again. --->  oh
#  dim light that i was frightened and ranout again. oh --->  it
#  light that i was frightened and ranout again. oh it --->  is
#  that i was frightened and ranout again. oh it is --->  so
#  i was frightened and ranout again. oh it is so --->  dreadfully
#  was frightened and ranout again. oh it is so dreadfully --->  still
#  frightened and ranout again. oh it is so dreadfully still --->  in
#  and ranout again. oh it is so dreadfully still in --->  thereonly
#  ranout again. oh it is so dreadfully still in thereonly --->  that
#  again. oh it is so dreadfully still in thereonly that --->  said
#  oh it is so dreadfully still in thereonly that said --->  he
#  it is so dreadfully still in thereonly that said he --->  looking
#  is so dreadfully still in thereonly that said he looking --->  at
#  so dreadfully still in thereonly that said he looking at --->  me
#  dreadfully still in thereonly that said he looking at me --->  keenly.why
#  still in thereonly that said he looking at me keenly.why --->  what
#  in thereonly that said he looking at me keenly.why what --->  did
#  thereonly that said he looking at me keenly.why what did --->  you
#  that said he looking at me keenly.why what did you --->  think
#  said he looking at me keenly.why what did you think --->  i
#  he looking at me keenly.why what did you think i --->  asked.why
#  looking at me keenly.why what did you think i asked.why --->  do
#  at me keenly.why what did you think i asked.why do --->  you
#  me keenly.why what did you think i asked.why do you --->  think
#  keenly.why what did you think i asked.why do you think --->  that
#  what did you think i asked.why do you think that --->  i
#  did you think i asked.why do you think that i --->  lock
#  you think i asked.why do you think that i lock --->  this
#  think i asked.why do you think that i lock this --->  doori
#  i asked.why do you think that i lock this doori --->  am
#  asked.why do you think that i lock this doori am --->  sure
#  do you think that i lock this doori am sure --->  that
#  you think that i lock this doori am sure that --->  i
#  think that i lock this doori am sure that i --->  do
#  that i lock this doori am sure that i do --->  not
#  i lock this doori am sure that i do not --->  know.it
#  lock this doori am sure that i do not know.it --->  is
#  this doori am sure that i do not know.it is --->  to
#  doori am sure that i do not know.it is to --->  keep
#  am sure that i do not know.it is to keep --->  people
#  sure that i do not know.it is to keep people --->  out
#  that i do not know.it is to keep people out --->  who
#  i do not know.it is to keep people out who --->  have
#  do not know.it is to keep people out who have --->  no
#  not know.it is to keep people out who have no --->  business
#  know.it is to keep people out who have no business --->  there.
#  is to keep people out who have no business there. --->  do
#  to keep people out who have no business there. do --->  you
#  keep people out who have no business there. do you --->  see
#  people out who have no business there. do you see --->  hewas
#  out who have no business there. do you see hewas --->  still
#  who have no business there. do you see hewas still --->  smiling
#  have no business there. do you see hewas still smiling --->  in
#  no business there. do you see hewas still smiling in --->  the
#  business there. do you see hewas still smiling in the --->  most
#  there. do you see hewas still smiling in the most --->  amiable
#  do you see hewas still smiling in the most amiable --->  manner.i
#  you see hewas still smiling in the most amiable manner.i --->  am
#  see hewas still smiling in the most amiable manner.i am --->  sure
#  hewas still smiling in the most amiable manner.i am sure --->  if
#  still smiling in the most amiable manner.i am sure if --->  i
#  smiling in the most amiable manner.i am sure if i --->  had
#  in the most amiable manner.i am sure if i had --->  knownwell
#  the most amiable manner.i am sure if i had knownwell --->  then
#  most amiable manner.i am sure if i had knownwell then --->  you
#  amiable manner.i am sure if i had knownwell then you --->  know
#  manner.i am sure if i had knownwell then you know --->  now.
#  am sure if i had knownwell then you know now. --->  and
#  sure if i had knownwell then you know now. and --->  if
#  if i had knownwell then you know now. and if --->  you
#  i had knownwell then you know now. and if you --->  ever
#  had knownwell then you know now. and if you ever --->  put
#  knownwell then you know now. and if you ever put --->  your
#  then you know now. and if you ever put your --->  foot
#  you know now. and if you ever put your foot --->  over
#  know now. and if you ever put your foot over --->  thatthreshold
#  now. and if you ever put your foot over thatthreshold --->  againhere
#  and if you ever put your foot over thatthreshold againhere --->  in
#  if you ever put your foot over thatthreshold againhere in --->  an
#  you ever put your foot over thatthreshold againhere in an --->  instant
#  ever put your foot over thatthreshold againhere in an instant --->  the
#  put your foot over thatthreshold againhere in an instant the --->  smile
#  your foot over thatthreshold againhere in an instant the smile --->  hardened
#  foot over thatthreshold againhere in an instant the smile hardened --->  into
#  over thatthreshold againhere in an instant the smile hardened into --->  a
#  thatthreshold againhere in an instant the smile hardened into a --->  grin
#  againhere in an instant the smile hardened into a grin --->  ofrage
#  in an instant the smile hardened into a grin ofrage --->  and
#  an instant the smile hardened into a grin ofrage and --->  he
#  instant the smile hardened into a grin ofrage and he --->  glared
#  the smile hardened into a grin ofrage and he glared --->  down
#  smile hardened into a grin ofrage and he glared down --->  at
#  hardened into a grin ofrage and he glared down at --->  me
#  into a grin ofrage and he glared down at me --->  with
#  a grin ofrage and he glared down at me with --->  the
#  grin ofrage and he glared down at me with the --->  face
#  ofrage and he glared down at me with the face --->  of
#  and he glared down at me with the face of --->  a
#  he glared down at me with the face of a --->  demonill
#  glared down at me with the face of a demonill --->  throw
#  down at me with the face of a demonill throw --->  youto
#  at me with the face of a demonill throw youto --->  the
#  me with the face of a demonill throw youto the --->  mastiff.i
#  with the face of a demonill throw youto the mastiff.i --->  was
#  the face of a demonill throw youto the mastiff.i was --->  so
#  face of a demonill throw youto the mastiff.i was so --->  terrified
#  of a demonill throw youto the mastiff.i was so terrified --->  that
#  a demonill throw youto the mastiff.i was so terrified that --->  i
#  demonill throw youto the mastiff.i was so terrified that i --->  do
#  throw youto the mastiff.i was so terrified that i do --->  not
#  youto the mastiff.i was so terrified that i do not --->  know
#  the mastiff.i was so terrified that i do not know --->  what
#  mastiff.i was so terrified that i do not know what --->  i
#  was so terrified that i do not know what i --->  did.
#  so terrified that i do not know what i did. --->  i
#  terrified that i do not know what i did. i --->  suppose
#  that i do not know what i did. i suppose --->  that
#  i do not know what i did. i suppose that --->  imust
#  do not know what i did. i suppose that imust --->  have
#  not know what i did. i suppose that imust have --->  rushed
#  know what i did. i suppose that imust have rushed --->  past
#  what i did. i suppose that imust have rushed past --->  him
#  i did. i suppose that imust have rushed past him --->  into
#  did. i suppose that imust have rushed past him into --->  my
#  i suppose that imust have rushed past him into my --->  room.
#  suppose that imust have rushed past him into my room. --->  i
#  that imust have rushed past him into my room. i --->  remember
#  imust have rushed past him into my room. i remember --->  nothing
#  have rushed past him into my room. i remember nothing --->  until
#  rushed past him into my room. i remember nothing until --->  ifound
#  past him into my room. i remember nothing until ifound --->  myself
#  him into my room. i remember nothing until ifound myself --->  lying
#  into my room. i remember nothing until ifound myself lying --->  on
#  my room. i remember nothing until ifound myself lying on --->  my
#  room. i remember nothing until ifound myself lying on my --->  bed
#  i remember nothing until ifound myself lying on my bed --->  trembling
#  remember nothing until ifound myself lying on my bed trembling --->  all
#  nothing until ifound myself lying on my bed trembling all --->  over.
#  until ifound myself lying on my bed trembling all over. --->  then
#  ifound myself lying on my bed trembling all over. then --->  i
#  myself lying on my bed trembling all over. then i --->  thought
#  lying on my bed trembling all over. then i thought --->  of
#  on my bed trembling all over. then i thought of --->  youmr.
#  my bed trembling all over. then i thought of youmr. --->  holmes.
#  bed trembling all over. then i thought of youmr. holmes. --->  i
#  trembling all over. then i thought of youmr. holmes. i --->  could
#  all over. then i thought of youmr. holmes. i could --->  not
#  over. then i thought of youmr. holmes. i could not --->  live
#  then i thought of youmr. holmes. i could not live --->  there
#  i thought of youmr. holmes. i could not live there --->  longer
#  thought of youmr. holmes. i could not live there longer --->  without
#  of youmr. holmes. i could not live there longer without --->  some
#  youmr. holmes. i could not live there longer without some --->  advice.
#  holmes. i could not live there longer without some advice. --->  i
#  i could not live there longer without some advice. i --->  wasfrightened
#  could not live there longer without some advice. i wasfrightened --->  of
#  not live there longer without some advice. i wasfrightened of --->  the
#  live there longer without some advice. i wasfrightened of the --->  house
#  there longer without some advice. i wasfrightened of the house --->  of
#  longer without some advice. i wasfrightened of the house of --->  the
#  without some advice. i wasfrightened of the house of the --->  man
#  some advice. i wasfrightened of the house of the man --->  of
#  advice. i wasfrightened of the house of the man of --->  the
#  i wasfrightened of the house of the man of the --->  woman
#  wasfrightened of the house of the man of the woman --->  of
#  of the house of the man of the woman of --->  the
#  the house of the man of the woman of the --->  servantseven
#  house of the man of the woman of the servantseven --->  of
#  of the man of the woman of the servantseven of --->  the
#  the man of the woman of the servantseven of the --->  child.
#  man of the woman of the servantseven of the child. --->  they
#  of the woman of the servantseven of the child. they --->  were
#  the woman of the servantseven of the child. they were --->  all
#  woman of the servantseven of the child. they were all --->  horrible
#  of the servantseven of the child. they were all horrible --->  to
#  the servantseven of the child. they were all horrible to --->  me.
#  servantseven of the child. they were all horrible to me. --->  if
#  of the child. they were all horrible to me. if --->  i
#  the child. they were all horrible to me. if i --->  could
#  child. they were all horrible to me. if i could --->  only
#  they were all horrible to me. if i could only --->  bringyou
#  were all horrible to me. if i could only bringyou --->  down
#  all horrible to me. if i could only bringyou down --->  all
#  horrible to me. if i could only bringyou down all --->  would
#  to me. if i could only bringyou down all would --->  be
#  me. if i could only bringyou down all would be --->  well.
#  if i could only bringyou down all would be well. --->  of
#  i could only bringyou down all would be well. of --->  course
#  could only bringyou down all would be well. of course --->  i
#  only bringyou down all would be well. of course i --->  might
#  bringyou down all would be well. of course i might --->  have
#  down all would be well. of course i might have --->  fled
#  all would be well. of course i might have fled --->  from
#  would be well. of course i might have fled from --->  the
#  be well. of course i might have fled from the --->  housebut
#  well. of course i might have fled from the housebut --->  my
#  of course i might have fled from the housebut my --->  curiosity
#  course i might have fled from the housebut my curiosity --->  was
#  i might have fled from the housebut my curiosity was --->  almost
#  might have fled from the housebut my curiosity was almost --->  as
#  have fled from the housebut my curiosity was almost as --->  strong
#  fled from the housebut my curiosity was almost as strong --->  as
#  from the housebut my curiosity was almost as strong as --->  my
#  the housebut my curiosity was almost as strong as my --->  fears.
#  housebut my curiosity was almost as strong as my fears. --->  my
#  my curiosity was almost as strong as my fears. my --->  mind
#  curiosity was almost as strong as my fears. my mind --->  was
#  was almost as strong as my fears. my mind was --->  soonmade
#  almost as strong as my fears. my mind was soonmade --->  up.
#  as strong as my fears. my mind was soonmade up. --->  i
#  strong as my fears. my mind was soonmade up. i --->  would
#  as my fears. my mind was soonmade up. i would --->  send
#  my fears. my mind was soonmade up. i would send --->  you
#  fears. my mind was soonmade up. i would send you --->  a
#  my mind was soonmade up. i would send you a --->  wire.
#  mind was soonmade up. i would send you a wire. --->  i
#  was soonmade up. i would send you a wire. i --->  put
#  soonmade up. i would send you a wire. i put --->  on
#  up. i would send you a wire. i put on --->  my
#  i would send you a wire. i put on my --->  hat
#  would send you a wire. i put on my hat --->  and
#  send you a wire. i put on my hat and --->  cloak
#  you a wire. i put on my hat and cloak --->  went
#  a wire. i put on my hat and cloak went --->  downto
#  wire. i put on my hat and cloak went downto --->  the
#  i put on my hat and cloak went downto the --->  office
#  put on my hat and cloak went downto the office --->  which
#  on my hat and cloak went downto the office which --->  is
#  my hat and cloak went downto the office which is --->  about
#  hat and cloak went downto the office which is about --->  half
#  and cloak went downto the office which is about half --->  a
#  cloak went downto the office which is about half a --->  mile
#  went downto the office which is about half a mile --->  from
#  downto the office which is about half a mile from --->  the
#  the office which is about half a mile from the --->  house
#  office which is about half a mile from the house --->  and
#  which is about half a mile from the house and --->  thenreturned
#  is about half a mile from the house and thenreturned --->  feeling
#  about half a mile from the house and thenreturned feeling --->  very
#  half a mile from the house and thenreturned feeling very --->  much
#  a mile from the house and thenreturned feeling very much --->  easier.
#  mile from the house and thenreturned feeling very much easier. --->  a
#  from the house and thenreturned feeling very much easier. a --->  horrible
#  the house and thenreturned feeling very much easier. a horrible --->  doubt
#  house and thenreturned feeling very much easier. a horrible doubt --->  came
#  and thenreturned feeling very much easier. a horrible doubt came --->  into
#  thenreturned feeling very much easier. a horrible doubt came into --->  my
#  feeling very much easier. a horrible doubt came into my --->  mindas
#  very much easier. a horrible doubt came into my mindas --->  i
#  much easier. a horrible doubt came into my mindas i --->  approached
#  easier. a horrible doubt came into my mindas i approached --->  the
#  a horrible doubt came into my mindas i approached the --->  door
#  horrible doubt came into my mindas i approached the door --->  lest
#  doubt came into my mindas i approached the door lest --->  the
#  came into my mindas i approached the door lest the --->  dog
#  into my mindas i approached the door lest the dog --->  might
#  my mindas i approached the door lest the dog might --->  be
#  mindas i approached the door lest the dog might be --->  loose
#  i approached the door lest the dog might be loose --->  but
#  approached the door lest the dog might be loose but --->  i
#  the door lest the dog might be loose but i --->  rememberedthat
#  door lest the dog might be loose but i rememberedthat --->  toller
#  lest the dog might be loose but i rememberedthat toller --->  had
#  the dog might be loose but i rememberedthat toller had --->  drunk
#  dog might be loose but i rememberedthat toller had drunk --->  himself
#  might be loose but i rememberedthat toller had drunk himself --->  into
#  be loose but i rememberedthat toller had drunk himself into --->  a
#  loose but i rememberedthat toller had drunk himself into a --->  state
#  but i rememberedthat toller had drunk himself into a state --->  of
#  i rememberedthat toller had drunk himself into a state of --->  insensibility
#  rememberedthat toller had drunk himself into a state of insensibility --->  thatevening
#  toller had drunk himself into a state of insensibility thatevening --->  and
#  had drunk himself into a state of insensibility thatevening and --->  i
#  drunk himself into a state of insensibility thatevening and i --->  knew
#  himself into a state of insensibility thatevening and i knew --->  that
#  into a state of insensibility thatevening and i knew that --->  he
#  a state of insensibility thatevening and i knew that he --->  was
#  state of insensibility thatevening and i knew that he was --->  the
#  of insensibility thatevening and i knew that he was the --->  only
#  insensibility thatevening and i knew that he was the only --->  one
#  thatevening and i knew that he was the only one --->  in
#  and i knew that he was the only one in --->  the
#  i knew that he was the only one in the --->  household
#  knew that he was the only one in the household --->  who
#  that he was the only one in the household who --->  hadany
#  he was the only one in the household who hadany --->  influence
#  was the only one in the household who hadany influence --->  with
#  the only one in the household who hadany influence with --->  the
#  only one in the household who hadany influence with the --->  savage
#  one in the household who hadany influence with the savage --->  creature
#  in the household who hadany influence with the savage creature --->  or
#  the household who hadany influence with the savage creature or --->  who
#  household who hadany influence with the savage creature or who --->  would
#  who hadany influence with the savage creature or who would --->  venture
#  hadany influence with the savage creature or who would venture --->  to
#  influence with the savage creature or who would venture to --->  set
#  with the savage creature or who would venture to set --->  himfree.
#  the savage creature or who would venture to set himfree. --->  i
#  savage creature or who would venture to set himfree. i --->  slipped
#  creature or who would venture to set himfree. i slipped --->  in
#  or who would venture to set himfree. i slipped in --->  in
#  who would venture to set himfree. i slipped in in --->  safety
#  would venture to set himfree. i slipped in in safety --->  and
#  venture to set himfree. i slipped in in safety and --->  lay
#  to set himfree. i slipped in in safety and lay --->  awake
#  set himfree. i slipped in in safety and lay awake --->  half
#  himfree. i slipped in in safety and lay awake half --->  the
#  i slipped in in safety and lay awake half the --->  night
#  slipped in in safety and lay awake half the night --->  in
#  in in safety and lay awake half the night in --->  my
#  in safety and lay awake half the night in my --->  joy
#  safety and lay awake half the night in my joy --->  atthe
#  and lay awake half the night in my joy atthe --->  thought
#  lay awake half the night in my joy atthe thought --->  of
#  awake half the night in my joy atthe thought of --->  seeing
#  half the night in my joy atthe thought of seeing --->  you.
#  the night in my joy atthe thought of seeing you. --->  i
#  night in my joy atthe thought of seeing you. i --->  had
#  in my joy atthe thought of seeing you. i had --->  no
#  my joy atthe thought of seeing you. i had no --->  difficulty
#  joy atthe thought of seeing you. i had no difficulty --->  in
#  atthe thought of seeing you. i had no difficulty in --->  getting
#  thought of seeing you. i had no difficulty in getting --->  leave
#  of seeing you. i had no difficulty in getting leave --->  to
#  seeing you. i had no difficulty in getting leave to --->  comeinto
#  you. i had no difficulty in getting leave to comeinto --->  winchester
#  i had no difficulty in getting leave to comeinto winchester --->  this
#  had no difficulty in getting leave to comeinto winchester this --->  morning
#  no difficulty in getting leave to comeinto winchester this morning --->  but
#  difficulty in getting leave to comeinto winchester this morning but --->  i
#  in getting leave to comeinto winchester this morning but i --->  must
#  getting leave to comeinto winchester this morning but i must --->  be
#  leave to comeinto winchester this morning but i must be --->  back
#  to comeinto winchester this morning but i must be back --->  before
#  comeinto winchester this morning but i must be back before --->  three
#  winchester this morning but i must be back before three --->  oclockfor
#  this morning but i must be back before three oclockfor --->  mr.
#  morning but i must be back before three oclockfor mr. --->  and
#  but i must be back before three oclockfor mr. and --->  mrs.
#  i must be back before three oclockfor mr. and mrs. --->  rucastle
#  must be back before three oclockfor mr. and mrs. rucastle --->  are
#  be back before three oclockfor mr. and mrs. rucastle are --->  going
#  back before three oclockfor mr. and mrs. rucastle are going --->  on
#  before three oclockfor mr. and mrs. rucastle are going on --->  a
#  three oclockfor mr. and mrs. rucastle are going on a --->  visit
#  oclockfor mr. and mrs. rucastle are going on a visit --->  and
#  mr. and mrs. rucastle are going on a visit and --->  will
#  and mrs. rucastle are going on a visit and will --->  be
#  mrs. rucastle are going on a visit and will be --->  away
#  rucastle are going on a visit and will be away --->  allthe
#  are going on a visit and will be away allthe --->  evening
#  going on a visit and will be away allthe evening --->  so
#  on a visit and will be away allthe evening so --->  that
#  a visit and will be away allthe evening so that --->  i
#  visit and will be away allthe evening so that i --->  must
#  and will be away allthe evening so that i must --->  look
#  will be away allthe evening so that i must look --->  after
#  be away allthe evening so that i must look after --->  the
#  away allthe evening so that i must look after the --->  child.
#  allthe evening so that i must look after the child. --->  now
#  evening so that i must look after the child. now --->  i
#  so that i must look after the child. now i --->  have
#  that i must look after the child. now i have --->  told
#  i must look after the child. now i have told --->  youall
#  must look after the child. now i have told youall --->  my
#  look after the child. now i have told youall my --->  adventures
#  after the child. now i have told youall my adventures --->  mr.
#  the child. now i have told youall my adventures mr. --->  holmes
#  child. now i have told youall my adventures mr. holmes --->  and
#  now i have told youall my adventures mr. holmes and --->  i
#  i have told youall my adventures mr. holmes and i --->  should
#  have told youall my adventures mr. holmes and i should --->  be
#  told youall my adventures mr. holmes and i should be --->  very
#  youall my adventures mr. holmes and i should be very --->  glad
#  my adventures mr. holmes and i should be very glad --->  if
#  adventures mr. holmes and i should be very glad if --->  you
#  mr. holmes and i should be very glad if you --->  couldtell
#  holmes and i should be very glad if you couldtell --->  me
#  and i should be very glad if you couldtell me --->  what
#  i should be very glad if you couldtell me what --->  it
#  should be very glad if you couldtell me what it --->  all
#  be very glad if you couldtell me what it all --->  means
#  very glad if you couldtell me what it all means --->  and
#  glad if you couldtell me what it all means and --->  above
#  if you couldtell me what it all means and above --->  all
#  you couldtell me what it all means and above all --->  what
#  couldtell me what it all means and above all what --->  i
#  me what it all means and above all what i --->  should
#  what it all means and above all what i should --->  do.holmes
#  it all means and above all what i should do.holmes --->  and
#  all means and above all what i should do.holmes and --->  i
#  means and above all what i should do.holmes and i --->  had
#  and above all what i should do.holmes and i had --->  listened
#  above all what i should do.holmes and i had listened --->  spellbound
#  all what i should do.holmes and i had listened spellbound --->  to
#  what i should do.holmes and i had listened spellbound to --->  this
#  i should do.holmes and i had listened spellbound to this --->  extraordinary
#  should do.holmes and i had listened spellbound to this extraordinary --->  story.
#  do.holmes and i had listened spellbound to this extraordinary story. --->  myfriend
#  and i had listened spellbound to this extraordinary story. myfriend --->  rose
#  i had listened spellbound to this extraordinary story. myfriend rose --->  now
#  had listened spellbound to this extraordinary story. myfriend rose now --->  and
#  listened spellbound to this extraordinary story. myfriend rose now and --->  paced
#  spellbound to this extraordinary story. myfriend rose now and paced --->  up
#  to this extraordinary story. myfriend rose now and paced up --->  and
#  this extraordinary story. myfriend rose now and paced up and --->  down
#  extraordinary story. myfriend rose now and paced up and down --->  the
#  story. myfriend rose now and paced up and down the --->  room
#  myfriend rose now and paced up and down the room --->  his
#  rose now and paced up and down the room his --->  hands
#  now and paced up and down the room his hands --->  in
#  and paced up and down the room his hands in --->  hispockets
#  paced up and down the room his hands in hispockets --->  and
#  up and down the room his hands in hispockets and --->  an
#  and down the room his hands in hispockets and an --->  expression
#  down the room his hands in hispockets and an expression --->  of
#  the room his hands in hispockets and an expression of --->  the
#  room his hands in hispockets and an expression of the --->  most
#  his hands in hispockets and an expression of the most --->  profound
#  hands in hispockets and an expression of the most profound --->  gravity
#  in hispockets and an expression of the most profound gravity --->  upon
#  hispockets and an expression of the most profound gravity upon --->  his
#  and an expression of the most profound gravity upon his --->  face.is
#  an expression of the most profound gravity upon his face.is --->  toller
#  expression of the most profound gravity upon his face.is toller --->  still
#  of the most profound gravity upon his face.is toller still --->  drunk
#  the most profound gravity upon his face.is toller still drunk --->  he
#  most profound gravity upon his face.is toller still drunk he --->  asked.yes.
#  profound gravity upon his face.is toller still drunk he asked.yes. --->  i
#  gravity upon his face.is toller still drunk he asked.yes. i --->  heard
#  upon his face.is toller still drunk he asked.yes. i heard --->  his
#  his face.is toller still drunk he asked.yes. i heard his --->  wife
#  face.is toller still drunk he asked.yes. i heard his wife --->  tell
#  toller still drunk he asked.yes. i heard his wife tell --->  mrs.
#  still drunk he asked.yes. i heard his wife tell mrs. --->  rucastle
#  drunk he asked.yes. i heard his wife tell mrs. rucastle --->  that
#  he asked.yes. i heard his wife tell mrs. rucastle that --->  she
#  asked.yes. i heard his wife tell mrs. rucastle that she --->  could
#  i heard his wife tell mrs. rucastle that she could --->  do
#  heard his wife tell mrs. rucastle that she could do --->  nothingwith
#  his wife tell mrs. rucastle that she could do nothingwith --->  him.that
#  wife tell mrs. rucastle that she could do nothingwith him.that --->  is
#  tell mrs. rucastle that she could do nothingwith him.that is --->  well.
#  mrs. rucastle that she could do nothingwith him.that is well. --->  and
#  rucastle that she could do nothingwith him.that is well. and --->  the
#  that she could do nothingwith him.that is well. and the --->  rucastles
#  she could do nothingwith him.that is well. and the rucastles --->  go
#  could do nothingwith him.that is well. and the rucastles go --->  out
#  do nothingwith him.that is well. and the rucastles go out --->  tonightyes.is
#  nothingwith him.that is well. and the rucastles go out tonightyes.is --->  there
#  him.that is well. and the rucastles go out tonightyes.is there --->  a
#  is well. and the rucastles go out tonightyes.is there a --->  cellar
#  well. and the rucastles go out tonightyes.is there a cellar --->  with
#  and the rucastles go out tonightyes.is there a cellar with --->  a
#  the rucastles go out tonightyes.is there a cellar with a --->  good
#  rucastles go out tonightyes.is there a cellar with a good --->  strong
#  go out tonightyes.is there a cellar with a good strong --->  lockyes
#  out tonightyes.is there a cellar with a good strong lockyes --->  the
#  tonightyes.is there a cellar with a good strong lockyes the --->  winecellar.you
#  there a cellar with a good strong lockyes the winecellar.you --->  seem
#  a cellar with a good strong lockyes the winecellar.you seem --->  to
#  cellar with a good strong lockyes the winecellar.you seem to --->  me
#  with a good strong lockyes the winecellar.you seem to me --->  to
#  a good strong lockyes the winecellar.you seem to me to --->  have
#  good strong lockyes the winecellar.you seem to me to have --->  acted
#  strong lockyes the winecellar.you seem to me to have acted --->  all
#  lockyes the winecellar.you seem to me to have acted all --->  through
#  the winecellar.you seem to me to have acted all through --->  this
#  winecellar.you seem to me to have acted all through this --->  matter
#  seem to me to have acted all through this matter --->  like
#  to me to have acted all through this matter like --->  a
#  me to have acted all through this matter like a --->  very
#  to have acted all through this matter like a very --->  braveand
#  have acted all through this matter like a very braveand --->  sensible
#  acted all through this matter like a very braveand sensible --->  girl
#  all through this matter like a very braveand sensible girl --->  miss
#  through this matter like a very braveand sensible girl miss --->  hunter.
#  this matter like a very braveand sensible girl miss hunter. --->  do
#  matter like a very braveand sensible girl miss hunter. do --->  you
#  like a very braveand sensible girl miss hunter. do you --->  think
#  a very braveand sensible girl miss hunter. do you think --->  that
#  very braveand sensible girl miss hunter. do you think that --->  you
#  braveand sensible girl miss hunter. do you think that you --->  could
#  sensible girl miss hunter. do you think that you could --->  perform
#  girl miss hunter. do you think that you could perform --->  onemore
#  miss hunter. do you think that you could perform onemore --->  feat
#  hunter. do you think that you could perform onemore feat --->  i
#  do you think that you could perform onemore feat i --->  should
#  you think that you could perform onemore feat i should --->  not
#  think that you could perform onemore feat i should not --->  ask
#  that you could perform onemore feat i should not ask --->  it
#  you could perform onemore feat i should not ask it --->  of
#  could perform onemore feat i should not ask it of --->  you
#  perform onemore feat i should not ask it of you --->  if
#  onemore feat i should not ask it of you if --->  i
#  feat i should not ask it of you if i --->  did
#  i should not ask it of you if i did --->  not
#  should not ask it of you if i did not --->  think
#  not ask it of you if i did not think --->  you
#  ask it of you if i did not think you --->  a
#  it of you if i did not think you a --->  quiteexceptional
#  of you if i did not think you a quiteexceptional --->  woman.i
#  you if i did not think you a quiteexceptional woman.i --->  will
#  if i did not think you a quiteexceptional woman.i will --->  try.
#  i did not think you a quiteexceptional woman.i will try. --->  what
#  did not think you a quiteexceptional woman.i will try. what --->  is
#  not think you a quiteexceptional woman.i will try. what is --->  itwe
#  think you a quiteexceptional woman.i will try. what is itwe --->  shall
#  you a quiteexceptional woman.i will try. what is itwe shall --->  be
#  a quiteexceptional woman.i will try. what is itwe shall be --->  at
#  quiteexceptional woman.i will try. what is itwe shall be at --->  the
#  woman.i will try. what is itwe shall be at the --->  copper
#  will try. what is itwe shall be at the copper --->  beeches
#  try. what is itwe shall be at the copper beeches --->  by
#  what is itwe shall be at the copper beeches by --->  seven
#  is itwe shall be at the copper beeches by seven --->  oclock
#  itwe shall be at the copper beeches by seven oclock --->  my
#  shall be at the copper beeches by seven oclock my --->  friend
#  be at the copper beeches by seven oclock my friend --->  and
#  at the copper beeches by seven oclock my friend and --->  i.the
#  the copper beeches by seven oclock my friend and i.the --->  rucastles
#  copper beeches by seven oclock my friend and i.the rucastles --->  will
#  beeches by seven oclock my friend and i.the rucastles will --->  be
#  by seven oclock my friend and i.the rucastles will be --->  gone
#  seven oclock my friend and i.the rucastles will be gone --->  by
#  oclock my friend and i.the rucastles will be gone by --->  that
#  my friend and i.the rucastles will be gone by that --->  time
#  friend and i.the rucastles will be gone by that time --->  and
#  and i.the rucastles will be gone by that time and --->  toller
#  i.the rucastles will be gone by that time and toller --->  will
#  rucastles will be gone by that time and toller will --->  we
#  will be gone by that time and toller will we --->  hope
#  be gone by that time and toller will we hope --->  beincapable.
#  gone by that time and toller will we hope beincapable. --->  there
#  by that time and toller will we hope beincapable. there --->  only
#  that time and toller will we hope beincapable. there only --->  remains
#  time and toller will we hope beincapable. there only remains --->  mrs.
#  and toller will we hope beincapable. there only remains mrs. --->  toller
#  toller will we hope beincapable. there only remains mrs. toller --->  who
#  will we hope beincapable. there only remains mrs. toller who --->  might
#  we hope beincapable. there only remains mrs. toller who might --->  give
#  hope beincapable. there only remains mrs. toller who might give --->  the
#  beincapable. there only remains mrs. toller who might give the --->  alarm.
#  there only remains mrs. toller who might give the alarm. --->  ifyou
#  only remains mrs. toller who might give the alarm. ifyou --->  could
#  remains mrs. toller who might give the alarm. ifyou could --->  send
#  mrs. toller who might give the alarm. ifyou could send --->  her
#  toller who might give the alarm. ifyou could send her --->  into
#  who might give the alarm. ifyou could send her into --->  the
#  might give the alarm. ifyou could send her into the --->  cellar
#  give the alarm. ifyou could send her into the cellar --->  on
#  the alarm. ifyou could send her into the cellar on --->  some
#  alarm. ifyou could send her into the cellar on some --->  errand
#  ifyou could send her into the cellar on some errand --->  and
#  could send her into the cellar on some errand and --->  then
#  send her into the cellar on some errand and then --->  turn
#  her into the cellar on some errand and then turn --->  thekey
#  into the cellar on some errand and then turn thekey --->  upon
#  the cellar on some errand and then turn thekey upon --->  her
#  cellar on some errand and then turn thekey upon her --->  you
#  on some errand and then turn thekey upon her you --->  would
#  some errand and then turn thekey upon her you would --->  facilitate
#  errand and then turn thekey upon her you would facilitate --->  matters
#  and then turn thekey upon her you would facilitate matters --->  immensely.i
#  then turn thekey upon her you would facilitate matters immensely.i --->  will
#  turn thekey upon her you would facilitate matters immensely.i will --->  do
#  thekey upon her you would facilitate matters immensely.i will do --->  it.excellent
#  upon her you would facilitate matters immensely.i will do it.excellent --->  we
#  her you would facilitate matters immensely.i will do it.excellent we --->  shall
#  you would facilitate matters immensely.i will do it.excellent we shall --->  then
#  would facilitate matters immensely.i will do it.excellent we shall then --->  look
#  facilitate matters immensely.i will do it.excellent we shall then look --->  thoroughly
#  matters immensely.i will do it.excellent we shall then look thoroughly --->  into
#  immensely.i will do it.excellent we shall then look thoroughly into --->  the
#  will do it.excellent we shall then look thoroughly into the --->  affair.
#  do it.excellent we shall then look thoroughly into the affair. --->  of
#  it.excellent we shall then look thoroughly into the affair. of --->  coursethere
#  we shall then look thoroughly into the affair. of coursethere --->  is
#  shall then look thoroughly into the affair. of coursethere is --->  only
#  then look thoroughly into the affair. of coursethere is only --->  one
#  look thoroughly into the affair. of coursethere is only one --->  feasible
#  thoroughly into the affair. of coursethere is only one feasible --->  explanation.
#  into the affair. of coursethere is only one feasible explanation. --->  you
#  the affair. of coursethere is only one feasible explanation. you --->  have
#  affair. of coursethere is only one feasible explanation. you have --->  been
#  of coursethere is only one feasible explanation. you have been --->  brought
#  coursethere is only one feasible explanation. you have been brought --->  there
#  is only one feasible explanation. you have been brought there --->  topersonate
#  only one feasible explanation. you have been brought there topersonate --->  someone
#  one feasible explanation. you have been brought there topersonate someone --->  and
#  feasible explanation. you have been brought there topersonate someone and --->  the
#  explanation. you have been brought there topersonate someone and the --->  real
#  you have been brought there topersonate someone and the real --->  person
#  have been brought there topersonate someone and the real person --->  is
#  been brought there topersonate someone and the real person is --->  imprisoned
#  brought there topersonate someone and the real person is imprisoned --->  in
#  there topersonate someone and the real person is imprisoned in --->  this
#  topersonate someone and the real person is imprisoned in this --->  chamber.that
#  someone and the real person is imprisoned in this chamber.that --->  is
#  and the real person is imprisoned in this chamber.that is --->  obvious.
#  the real person is imprisoned in this chamber.that is obvious. --->  as
#  real person is imprisoned in this chamber.that is obvious. as --->  to
#  person is imprisoned in this chamber.that is obvious. as to --->  who
#  is imprisoned in this chamber.that is obvious. as to who --->  this
#  imprisoned in this chamber.that is obvious. as to who this --->  prisoner
#  in this chamber.that is obvious. as to who this prisoner --->  is
#  this chamber.that is obvious. as to who this prisoner is --->  i
#  chamber.that is obvious. as to who this prisoner is i --->  have
#  is obvious. as to who this prisoner is i have --->  no
#  obvious. as to who this prisoner is i have no --->  doubt
#  as to who this prisoner is i have no doubt --->  that
#  to who this prisoner is i have no doubt that --->  it
#  who this prisoner is i have no doubt that it --->  isthe
#  this prisoner is i have no doubt that it isthe --->  daughter
#  prisoner is i have no doubt that it isthe daughter --->  miss
#  is i have no doubt that it isthe daughter miss --->  alice
#  i have no doubt that it isthe daughter miss alice --->  rucastle
#  have no doubt that it isthe daughter miss alice rucastle --->  if
#  no doubt that it isthe daughter miss alice rucastle if --->  i
#  doubt that it isthe daughter miss alice rucastle if i --->  remember
#  that it isthe daughter miss alice rucastle if i remember --->  right
#  it isthe daughter miss alice rucastle if i remember right --->  who
#  isthe daughter miss alice rucastle if i remember right who --->  was
#  daughter miss alice rucastle if i remember right who was --->  said
#  miss alice rucastle if i remember right who was said --->  tohave
#  alice rucastle if i remember right who was said tohave --->  gone
#  rucastle if i remember right who was said tohave gone --->  to
#  if i remember right who was said tohave gone to --->  america.
#  i remember right who was said tohave gone to america. --->  you
#  remember right who was said tohave gone to america. you --->  were
#  right who was said tohave gone to america. you were --->  chosen
#  who was said tohave gone to america. you were chosen --->  doubtless
#  was said tohave gone to america. you were chosen doubtless --->  as
#  said tohave gone to america. you were chosen doubtless as --->  resembling
#  tohave gone to america. you were chosen doubtless as resembling --->  her
# ...
#  us with offers to donate.international donations are gratefully accepted but --->  we
#  with offers to donate.international donations are gratefully accepted but we --->  cannot
#  offers to donate.international donations are gratefully accepted but we cannot --->  makeany
#  to donate.international donations are gratefully accepted but we cannot makeany --->  statements
#  donate.international donations are gratefully accepted but we cannot makeany statements --->  concerning
#  donations are gratefully accepted but we cannot makeany statements concerning --->  tax
#  are gratefully accepted but we cannot makeany statements concerning tax --->  treatment
#  gratefully accepted but we cannot makeany statements concerning tax treatment --->  of
#  accepted but we cannot makeany statements concerning tax treatment of --->  donations
#  but we cannot makeany statements concerning tax treatment of donations --->  received
#  we cannot makeany statements concerning tax treatment of donations received --->  fromoutside
#  cannot makeany statements concerning tax treatment of donations received fromoutside --->  the
#  makeany statements concerning tax treatment of donations received fromoutside the --->  united
#  statements concerning tax treatment of donations received fromoutside the united --->  states.
#  concerning tax treatment of donations received fromoutside the united states. --->  u.s.
#  tax treatment of donations received fromoutside the united states. u.s. --->  laws
#  treatment of donations received fromoutside the united states. u.s. laws --->  alone
#  of donations received fromoutside the united states. u.s. laws alone --->  swamp
#  donations received fromoutside the united states. u.s. laws alone swamp --->  our
#  received fromoutside the united states. u.s. laws alone swamp our --->  small
#  fromoutside the united states. u.s. laws alone swamp our small --->  staff.please
#  the united states. u.s. laws alone swamp our small staff.please --->  check
#  united states. u.s. laws alone swamp our small staff.please check --->  the
#  states. u.s. laws alone swamp our small staff.please check the --->  project
#  u.s. laws alone swamp our small staff.please check the project --->  gutenberg
#  laws alone swamp our small staff.please check the project gutenberg --->  web
#  alone swamp our small staff.please check the project gutenberg web --->  pages
#  swamp our small staff.please check the project gutenberg web pages --->  for
#  our small staff.please check the project gutenberg web pages for --->  current
#  small staff.please check the project gutenberg web pages for current --->  donationmethods
#  staff.please check the project gutenberg web pages for current donationmethods --->  and
#  check the project gutenberg web pages for current donationmethods and --->  addresses.
#  the project gutenberg web pages for current donationmethods and addresses. --->  donations
#  project gutenberg web pages for current donationmethods and addresses. donations --->  are
#  gutenberg web pages for current donationmethods and addresses. donations are --->  accepted
#  web pages for current donationmethods and addresses. donations are accepted --->  in
#  pages for current donationmethods and addresses. donations are accepted in --->  a
#  for current donationmethods and addresses. donations are accepted in a --->  number
#  current donationmethods and addresses. donations are accepted in a number --->  of
#  donationmethods and addresses. donations are accepted in a number of --->  otherways
#  and addresses. donations are accepted in a number of otherways --->  including
#  addresses. donations are accepted in a number of otherways including --->  checks
#  donations are accepted in a number of otherways including checks --->  online
#  are accepted in a number of otherways including checks online --->  payments
#  accepted in a number of otherways including checks online payments --->  and
#  in a number of otherways including checks online payments and --->  credit
#  a number of otherways including checks online payments and credit --->  card
#  number of otherways including checks online payments and credit card --->  donations.
#  of otherways including checks online payments and credit card donations. --->  todonate
#  otherways including checks online payments and credit card donations. todonate --->  please
#  including checks online payments and credit card donations. todonate please --->  visit
#  checks online payments and credit card donations. todonate please visit --->  www.gutenberg.orgdonate.section
#  online payments and credit card donations. todonate please visit www.gutenberg.orgdonate.section --->  5.
#  payments and credit card donations. todonate please visit www.gutenberg.orgdonate.section 5. --->  general
#  and credit card donations. todonate please visit www.gutenberg.orgdonate.section 5. general --->  information
#  credit card donations. todonate please visit www.gutenberg.orgdonate.section 5. general information --->  about
#  card donations. todonate please visit www.gutenberg.orgdonate.section 5. general information about --->  project
#  donations. todonate please visit www.gutenberg.orgdonate.section 5. general information about project --->  gutenberg
#  todonate please visit www.gutenberg.orgdonate.section 5. general information about project gutenberg --->  electronicworksprofessor
#  please visit www.gutenberg.orgdonate.section 5. general information about project gutenberg electronicworksprofessor --->  michael
#  visit www.gutenberg.orgdonate.section 5. general information about project gutenberg electronicworksprofessor michael --->  s.
#  www.gutenberg.orgdonate.section 5. general information about project gutenberg electronicworksprofessor michael s. --->  hart
#  5. general information about project gutenberg electronicworksprofessor michael s. hart --->  was
#  general information about project gutenberg electronicworksprofessor michael s. hart was --->  the
#  information about project gutenberg electronicworksprofessor michael s. hart was the --->  originator
#  about project gutenberg electronicworksprofessor michael s. hart was the originator --->  of
#  project gutenberg electronicworksprofessor michael s. hart was the originator of --->  the
#  gutenberg electronicworksprofessor michael s. hart was the originator of the --->  projectgutenberg
#  electronicworksprofessor michael s. hart was the originator of the projectgutenberg --->  concept
#  michael s. hart was the originator of the projectgutenberg concept --->  of
#  s. hart was the originator of the projectgutenberg concept of --->  a
#  hart was the originator of the projectgutenberg concept of a --->  library
#  was the originator of the projectgutenberg concept of a library --->  of
#  the originator of the projectgutenberg concept of a library of --->  electronic
#  originator of the projectgutenberg concept of a library of electronic --->  works
#  of the projectgutenberg concept of a library of electronic works --->  that
#  the projectgutenberg concept of a library of electronic works that --->  could
#  projectgutenberg concept of a library of electronic works that could --->  befreely
#  concept of a library of electronic works that could befreely --->  shared
#  of a library of electronic works that could befreely shared --->  with
#  a library of electronic works that could befreely shared with --->  anyone.
#  library of electronic works that could befreely shared with anyone. --->  for
#  of electronic works that could befreely shared with anyone. for --->  forty
#  electronic works that could befreely shared with anyone. for forty --->  years
#  works that could befreely shared with anyone. for forty years --->  he
#  that could befreely shared with anyone. for forty years he --->  produced
#  could befreely shared with anyone. for forty years he produced --->  anddistributed
#  befreely shared with anyone. for forty years he produced anddistributed --->  project
#  shared with anyone. for forty years he produced anddistributed project --->  gutenberg
#  with anyone. for forty years he produced anddistributed project gutenberg --->  ebooks
#  anyone. for forty years he produced anddistributed project gutenberg ebooks --->  with
#  for forty years he produced anddistributed project gutenberg ebooks with --->  only
#  forty years he produced anddistributed project gutenberg ebooks with only --->  a
#  years he produced anddistributed project gutenberg ebooks with only a --->  loose
#  he produced anddistributed project gutenberg ebooks with only a loose --->  network
#  produced anddistributed project gutenberg ebooks with only a loose network --->  ofvolunteer
#  anddistributed project gutenberg ebooks with only a loose network ofvolunteer --->  support.project
#  project gutenberg ebooks with only a loose network ofvolunteer support.project --->  gutenberg
#  gutenberg ebooks with only a loose network ofvolunteer support.project gutenberg --->  ebooks
#  ebooks with only a loose network ofvolunteer support.project gutenberg ebooks --->  are
#  with only a loose network ofvolunteer support.project gutenberg ebooks are --->  often
#  only a loose network ofvolunteer support.project gutenberg ebooks are often --->  created
#  a loose network ofvolunteer support.project gutenberg ebooks are often created --->  from
#  loose network ofvolunteer support.project gutenberg ebooks are often created from --->  several
#  network ofvolunteer support.project gutenberg ebooks are often created from several --->  printededitions
#  ofvolunteer support.project gutenberg ebooks are often created from several printededitions --->  all
#  support.project gutenberg ebooks are often created from several printededitions all --->  of
#  gutenberg ebooks are often created from several printededitions all of --->  which
#  ebooks are often created from several printededitions all of which --->  are
#  are often created from several printededitions all of which are --->  confirmed
#  often created from several printededitions all of which are confirmed --->  as
#  created from several printededitions all of which are confirmed as --->  not
#  from several printededitions all of which are confirmed as not --->  protected
#  several printededitions all of which are confirmed as not protected --->  by
#  printededitions all of which are confirmed as not protected by --->  copyright
#  all of which are confirmed as not protected by copyright --->  inthe
#  of which are confirmed as not protected by copyright inthe --->  u.s.
#  which are confirmed as not protected by copyright inthe u.s. --->  unless
#  are confirmed as not protected by copyright inthe u.s. unless --->  a
#  confirmed as not protected by copyright inthe u.s. unless a --->  copyright
#  as not protected by copyright inthe u.s. unless a copyright --->  notice
#  not protected by copyright inthe u.s. unless a copyright notice --->  is
#  protected by copyright inthe u.s. unless a copyright notice is --->  included.
#  by copyright inthe u.s. unless a copyright notice is included. --->  thus
#  copyright inthe u.s. unless a copyright notice is included. thus --->  we
#  inthe u.s. unless a copyright notice is included. thus we --->  do
#  u.s. unless a copyright notice is included. thus we do --->  notnecessarily
#  unless a copyright notice is included. thus we do notnecessarily --->  keep
#  a copyright notice is included. thus we do notnecessarily keep --->  ebooks
#  copyright notice is included. thus we do notnecessarily keep ebooks --->  in
#  notice is included. thus we do notnecessarily keep ebooks in --->  compliance
#  is included. thus we do notnecessarily keep ebooks in compliance --->  with
#  included. thus we do notnecessarily keep ebooks in compliance with --->  any
#  thus we do notnecessarily keep ebooks in compliance with any --->  particular
#  we do notnecessarily keep ebooks in compliance with any particular --->  paperedition.most
#  do notnecessarily keep ebooks in compliance with any particular paperedition.most --->  people
#  notnecessarily keep ebooks in compliance with any particular paperedition.most people --->  start
#  keep ebooks in compliance with any particular paperedition.most people start --->  at
#  ebooks in compliance with any particular paperedition.most people start at --->  our
#  in compliance with any particular paperedition.most people start at our --->  website
#  compliance with any particular paperedition.most people start at our website --->  which
#  with any particular paperedition.most people start at our website which --->  has
#  any particular paperedition.most people start at our website which has --->  the
#  particular paperedition.most people start at our website which has the --->  main
#  paperedition.most people start at our website which has the main --->  pg
#  people start at our website which has the main pg --->  searchfacility
#  start at our website which has the main pg searchfacility --->  www.gutenberg.org.this
#  at our website which has the main pg searchfacility www.gutenberg.org.this --->  website
#  our website which has the main pg searchfacility www.gutenberg.org.this website --->  includes
#  website which has the main pg searchfacility www.gutenberg.org.this website includes --->  information
#  which has the main pg searchfacility www.gutenberg.org.this website includes information --->  about
#  has the main pg searchfacility www.gutenberg.org.this website includes information about --->  project
#  the main pg searchfacility www.gutenberg.org.this website includes information about project --->  gutenbergincluding
#  main pg searchfacility www.gutenberg.org.this website includes information about project gutenbergincluding --->  how
#  pg searchfacility www.gutenberg.org.this website includes information about project gutenbergincluding how --->  to
#  searchfacility www.gutenberg.org.this website includes information about project gutenbergincluding how to --->  make
#  www.gutenberg.org.this website includes information about project gutenbergincluding how to make --->  donations
#  website includes information about project gutenbergincluding how to make donations --->  to
#  includes information about project gutenbergincluding how to make donations to --->  the
#  information about project gutenbergincluding how to make donations to the --->  project
#  about project gutenbergincluding how to make donations to the project --->  gutenberg
#  project gutenbergincluding how to make donations to the project gutenberg --->  literaryarchive
#  gutenbergincluding how to make donations to the project gutenberg literaryarchive --->  foundation
#  how to make donations to the project gutenberg literaryarchive foundation --->  how
#  to make donations to the project gutenberg literaryarchive foundation how --->  to
#  make donations to the project gutenberg literaryarchive foundation how to --->  help
#  donations to the project gutenberg literaryarchive foundation how to help --->  produce
#  to the project gutenberg literaryarchive foundation how to help produce --->  our
#  the project gutenberg literaryarchive foundation how to help produce our --->  new
#  project gutenberg literaryarchive foundation how to help produce our new --->  ebooks
#  gutenberg literaryarchive foundation how to help produce our new ebooks --->  and
#  literaryarchive foundation how to help produce our new ebooks and --->  how
#  foundation how to help produce our new ebooks and how --->  tosubscribe
#  how to help produce our new ebooks and how tosubscribe --->  to
#  to help produce our new ebooks and how tosubscribe to --->  our
#  help produce our new ebooks and how tosubscribe to our --->  email
#  produce our new ebooks and how tosubscribe to our email --->  newsletter
#  our new ebooks and how tosubscribe to our email newsletter --->  to
#  new ebooks and how tosubscribe to our email newsletter to --->  hear
#  ebooks and how tosubscribe to our email newsletter to hear --->  about
#  and how tosubscribe to our email newsletter to hear about --->  new
#  how tosubscribe to our email newsletter to hear about new --->  ebooks.

# %%
class NextWordMLP(nn.Module):
    def __init__(self, vocab_size, emb_dim, hidden_size):
        super(NextWordMLP, self).__init__()
        self.emb = nn.Embedding(vocab_size, emb_dim)
        self.lin1 = nn.Linear(block_size * emb_dim, hidden_size)
        self.lin2 = nn.Linear(hidden_size, vocab_size)

    def forward(self, x):
        x = self.emb(x)
        x = x.view(x.shape[0], -1)  # Flatten the input
        x = F.relu(self.lin1(x))
        x = self.lin2(x)
        return x

# Initialize model
model_relu_32_10 = NextWordMLP(len(stoi) + 1, emb_dim=32, hidden_size=1024).to(device)

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# Step 1: Select a subset of words (for example, 100 words)
selected_words = selected_words = [
    "detect", "discover", "hide", "expose", "appear", "vanish",
    "observe", "notice", "truth", "lie", "crime", "justice",
    "clue", "evidence", "suspect", "accuse", "mystery", "solution",
    "search", "find", "silent", "speak", "solve", "unravel",
    "conceal", "reveal", "doubt", "certainty", "question", "answer",
    "sherlock", "watson", "holmes", "baker", "london", "night",
    "door", "case", "strange", "letter", "fear", "mind",
    "fact", "story", "secret", "danger", "friend", "enemy",
    "plan", "proof"
]
selected_indices = [stoi[word] for word in selected_words if word in stoi]

# Step 2: Get embeddings before training
with torch.no_grad():
    model_relu_32_10.eval()
    embeddings_before = model_relu_32_10.emb(torch.tensor(selected_indices).to(device)).cpu().numpy()

# %%
torch.cuda.empty_cache()

# %%
import torch
import torch.nn as nn
import time

# Set device to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Hyperparameters
emb_dim = 32 # Embedding dimension for words
hidden_size = 1024  # Size of hidden layer
block_size = 10 # Context length (number of words to predict the next one)
vocab_size = len(stoi)  # Size of the vocabulary
batch_size = 1500
print_every = 50
elapsed_time = []

# Initialize model, loss function, and optimizer
model_relu_32_10 = NextWordMLP(vocab_size + 1, emb_dim=emb_dim, hidden_size=hidden_size).to(device)
loss_fn = nn.CrossEntropyLoss()
opt = torch.optim.AdamW(model_relu_32_10.parameters(), lr=0.01)

# Move data to the GPU
X = X.to(device)
Y = Y.to(device)

# Training loop
for epoch in range(800):  # Loop for specified epochs

    model_relu_32_10.train()  # Set model to training mode

    # Mini-batch processing
    for i in range(0, X.shape[0], batch_size):
        x_batch = X[i:i + batch_size].to(device)  # Get the batch of input sequences
        y_batch = Y[i:i + batch_size].to(device)  # Get the batch of next word labels

        # Forward pass: predict the next word
        y_pred = model_relu_32_10(x_batch)

        # Compute loss
        loss = loss_fn(y_pred, y_batch)

        # Clear previous gradients
        opt.zero_grad()

        # Backpropagation: compute gradients
        loss.backward()

        # Update model parameters using optimizer
        opt.step()




    # Print loss at intervals
    if epoch % print_every == 0:
        print(f"Epoch {epoch}, Loss: {loss.item()}")

print("Training complete")
# Out:
# Epoch 0, Loss: 10.063281059265137
# Epoch 50, Loss: 0.0002414236223557964
# Epoch 100, Loss: 0.708616316318512
# Epoch 150, Loss: 0.00019994446483906358
# Epoch 200, Loss: 8.476447692373767e-05
# Epoch 250, Loss: 0.00034427366335876286
# Epoch 300, Loss: 0.00011792567966040224
# Epoch 350, Loss: 0.0005676035070791841
# Epoch 400, Loss: 0.00021248399571049958
# Epoch 450, Loss: 5.1368951972108334e-05
# Epoch 500, Loss: 0.00024170173855964094
# Epoch 550, Loss: 0.00011384316894691437
# Epoch 600, Loss: 0.0003056888817809522
# Epoch 650, Loss: 0.00020279259479139
# Epoch 700, Loss: 0.00018704305693972856
# Epoch 750, Loss: 0.00013860683247912675
# Training complete

# %%
torch.save(model_relu_32_10.state_dict(), 'model_relu_32_10.pth')

# %%
with torch.no_grad():
    embeddings_after = model_relu_32_10.emb(torch.tensor(selected_indices).to(device)).cpu().numpy()

# %%
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# Assuming `embeddings_before` and `embeddings_after` are initialized
sample_size = len(embeddings_before)
perplexity = min(5, sample_size - 1)  # Set a smaller perplexity if needed

# Initialize t-SNE with the adjusted perplexity
tsne = TSNE(n_components=2, perplexity=perplexity, random_state=0)
embeddings_before_2d = tsne.fit_transform(embeddings_before)
embeddings_after_2d = tsne.fit_transform(embeddings_after)

# Adjust selected_words to match the length of embeddings
selected_words = selected_words[:len(embeddings_before_2d)]

# Plot function
def plot_embeddings(embeddings, words, title):
    plt.figure(figsize=(10, 7))
    for i, word in enumerate(words):
        x, y = embeddings[i]
        plt.scatter(x, y)
        plt.text(x + 0.02, y + 0.02, word, fontsize=12)
    plt.title(title)
    plt.xlabel("Dimension 1")
    plt.ylabel("Dimension 2")
    plt.show()

# Plot before and after training
plot_embeddings(embeddings_before_2d, selected_words, "Embeddings Before Training")
plot_embeddings(embeddings_after_2d, selected_words, "Embeddings After Training")

# %%
def predict_next_word(model, context_words, top_k=1):
    model.eval()  # Set the model to evaluation mode

    # Preprocess the input (convert words to indices)
    context_indices = [stoi[word] for word in context_words]

    # Convert to tensor and move to GPU
    context_tensor = torch.tensor(context_indices, dtype=torch.long).unsqueeze(0).to(device)

    with torch.no_grad():
        output = model(context_tensor)
        probabilities = F.softmax(output, dim=-1)

        # Get the top_k predictions
        top_k_probs, top_k_indices = torch.topk(probabilities, top_k, dim=-1)

        predicted_words = [list(stoi.keys())[index.item()] for index in top_k_indices.squeeze()]

    return predicted_words

# Example usage
context = ["the", "cat", "is", "sitting", "on","the","mat","and","looking","at"]
predicted_word = predict_next_word(model_relu_32_10, context, top_k=3)
print("Predicted next words:", predicted_word)
# Out:
# Predicted next words: ['theaffairs', 'two.', 'course.']
